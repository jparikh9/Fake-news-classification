# %%
import pandas as panda
import numpy as num
from scipy.sparse import coo_matrix, vstack, hstack

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.naive_bayes import MultinomialNB

# %%
#read preprocessed data from file
train_data = panda.read_csv("train_preprocessed.csv", index_col='id')
print(train_data.shape)
train_data.head()
# Out:
# (192236, 5)
#         tid1  tid2                                          title1_en  \
# id
# 195611     0     1  two new oldage insurance benefit old people ru...
# 191474     2     3  if come shenzhen sooner later son also come le...
# 25300      2     4  if come shenzhen sooner later son also come le...
# 123757     2     8  if come shenzhen sooner later son also come le...
# 141761     2    11  if come shenzhen sooner later son also come le...
#
#                                                 title2_en      label
# id
# 195611  police disprove bird nest congress person get ...  unrelated
# 191474  shenzhens gdp outstrips hong kong shenzhen sta...  unrelated
# 25300   gdp overtopped hong kong shenzhen clarified li...  unrelated
# 123757  shenzhens gdp overtakes hong kong bureau stati...  unrelated
# 141761  shenzhens gdp outpaces hong kong defending rum...  unrelated

# %%
#dropping null values from file
train_data = train_data.dropna()
print(train_data.shape)
train_data.head()
# Out:
# (192211, 5)
#         tid1  tid2                                          title1_en  \
# id
# 195611     0     1  two new oldage insurance benefit old people ru...
# 191474     2     3  if come shenzhen sooner later son also come le...
# 25300      2     4  if come shenzhen sooner later son also come le...
# 123757     2     8  if come shenzhen sooner later son also come le...
# 141761     2    11  if come shenzhen sooner later son also come le...
#
#                                                 title2_en      label
# id
# 195611  police disprove bird nest congress person get ...  unrelated
# 191474  shenzhens gdp outstrips hong kong shenzhen sta...  unrelated
# 25300   gdp overtopped hong kong shenzhen clarified li...  unrelated
# 123757  shenzhens gdp overtakes hong kong bureau stati...  unrelated
# 141761  shenzhens gdp outpaces hong kong defending rum...  unrelated

# %%
#vectorizing using TF-IDF
title1_vector = TfidfVectorizer(analyzer='word',stop_words= 'english').fit(train_data['title1_en'])
title1_tfidf_vector = title1_vector.transform(train_data['title1_en'])

# %%
title1_tfidf_vector.shape
# Out:
# (192211, 24626)

# %%
#vectorizing title2 column seperately
title2_tfidf_vector = title1_vector.transform(train_data['title2_en'])

# %%
#stacking to matrix in order to increase columns
title_stack = hstack([title1_tfidf_vector, title2_tfidf_vector])

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(title_stack, train_data['label'], test_size=0.2)

# Create a Multinomial Naive Bayes model and train it on the training data
nb = MultinomialNB()
nb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# Predict the labels of the test data
y_pred = nb.predict(x_test)

# Evaluate the accuracy of the model on the test data
accuracy = nb.score(x_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7792836147022865

# %%
from sklearn import metrics

# Make predictions on the test data
y_pred = nb.predict(x_test)

# Print a classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       agreed       0.68      0.60      0.64     11313
#    disagreed       0.63      0.06      0.11       888
#    unrelated       0.81      0.88      0.85     26242
#
#     accuracy                           0.78     38443
#    macro avg       0.71      0.51      0.53     38443
# weighted avg       0.77      0.78      0.77     38443

# %%
#now applying trained model to predict labels in test data
test_data = panda.read_csv("test_preprocessed.csv", index_col='id')
print(test_data.shape)
test_data.head()
# Out:
# (64110, 4)
#           tid1    tid2                                          title1_en  \
# id
# 256442  100672  100673  great coat brother zhu zhu wen mandarin love s...
# 256443  162269  162270          nasa reveals fact ufo wreckage found moon
# 256444  157826  157854                       hollow tomato loaded hormone
# 256445  109579   74076  ange pavilion geoshui accurate matrimony match...
# 256446   15068   15085  50yearold busbus blow 8yearold child rumor rum...
#
#                                                 title2_en
# id
# 256442  lin xinsheng birth hard milking huo jianhua se...
# 256443  ufo found yuancun jiaocheng county shanxi shoc...
# 256444  li chenfan bingbing home photo netizen called ...
# 256445  master one eightcharacter presumption marriage...
# 256446          joe johnson disgruntled timing order myth

# %%
#dropping null values from test data
test_data = test_data.dropna()
print(test_data.shape)
test_data.head()
# Out:
# (64103, 4)
#           tid1    tid2                                          title1_en  \
# id
# 256442  100672  100673  great coat brother zhu zhu wen mandarin love s...
# 256443  162269  162270          nasa reveals fact ufo wreckage found moon
# 256444  157826  157854                       hollow tomato loaded hormone
# 256445  109579   74076  ange pavilion geoshui accurate matrimony match...
# 256446   15068   15085  50yearold busbus blow 8yearold child rumor rum...
#
#                                                 title2_en
# id
# 256442  lin xinsheng birth hard milking huo jianhua se...
# 256443  ufo found yuancun jiaocheng county shanxi shoc...
# 256444  li chenfan bingbing home photo netizen called ...
# 256445  master one eightcharacter presumption marriage...
# 256446          joe johnson disgruntled timing order myth

# %%
#vectorizing columns in test data
test_title1_tfidf_vector = title1_vector.transform(test_data['title1_en'])
test_title2_tfidf_vector = title1_vector.transform(test_data['title2_en'])
#stacking to form matric with incresed columns
test_title_stack = hstack([test_title1_tfidf_vector, test_title2_tfidf_vector])

# %%
#prediciting labels with the trained model
test_predict_data_labels = nb.predict(test_title_stack)

# %%
#adding labels to test data
test_data['label'] = test_predict_data_labels

# %%
test_data.head()
# Out:
#           tid1    tid2                                          title1_en  \
# id
# 256442  100672  100673  great coat brother zhu zhu wen mandarin love s...
# 256443  162269  162270          nasa reveals fact ufo wreckage found moon
# 256444  157826  157854                       hollow tomato loaded hormone
# 256445  109579   74076  ange pavilion geoshui accurate matrimony match...
# 256446   15068   15085  50yearold busbus blow 8yearold child rumor rum...
#
#                                                 title2_en      label
# id
# 256442  lin xinsheng birth hard milking huo jianhua se...  unrelated
# 256443  ufo found yuancun jiaocheng county shanxi shoc...  unrelated
# 256444  li chenfan bingbing home photo netizen called ...  unrelated
# 256445  master one eightcharacter presumption marriage...  unrelated
# 256446          joe johnson disgruntled timing order myth  unrelated

# %%
#extracting label column 
test_label_column = test_data['label']
print(test_label_column)
# Out:
# id
# 256442    unrelated
# 256443    unrelated
# 256444    unrelated
# 256445    unrelated
# 256446    unrelated
#             ...
# 320547       agreed
# 320548       agreed
# 320549    unrelated
# 320550    unrelated
# 320551       agreed
# Name: label, Length: 64103, dtype: object

# %%
#saving output file
from google.colab import files
test_label_column.to_csv('test_Naive_Bais_predicted.csv')
files.download('test_Naive_Bais_predicted.csv')
